# %%
pip install chatterbot==1.0.4
# Out:
# ...
#      ---------------------------------------- 66.3/66.3 kB 1.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 294.0/294.0 kB 4.5 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 5.7/5.7 MB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached python_dateutil-2.7.5-py2.py3-none-any.whl (225 kB)
# ...
#      -------------------------------------- 117.3/117.3 kB 6.7 MB/s eta 0:00:00
# ...
#      -------------------------------------- 394.5/394.5 kB 1.6 MB/s eta 0:00:00
# ...
#      -------------------------------------- 270.6/270.6 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.2.19-cp39-cp39-win_amd64.whl size=1114155 sha256=e58f05cc0ac9ad46fa3d3c38b6beeeb4b904e79a6e9796f790d149581b306a44
# ...

# %%
from chatterbot import ChatBot
from chatterbot.trainers import ChatterBotCorpusTrainer

# %%
# Inisialisasi ChatBot
chatbot = ChatBot('Chatbot Bahasa Indonesia')

# Menggunakan trainer untuk melatih ChatBot dengan data corpus
trainer = ChatterBotCorpusTrainer(chatbot)
trainer.train("chatterbot.corpus.indonesia")

# Fungsi untuk meminta input dari pengguna dan mendapatkan respon dari ChatBot
def get_bot_response(user_input):
    response = chatbot.get_response(user_input)
    return str(response)

# Loop utama untuk menjalankan chatbot
while True:
    user_input = input("User: ")
    if user_input.lower() == 'q':
        break
    bot_response = get_bot_response(user_input)
    print("Bot: " + bot_response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Inisialisasi ChatBot
# ----> 2 chatbot = ChatBot('Chatbot Bahasa Indonesia')
#       4 # Menggunakan trainer untuk melatih ChatBot dengan data corpus
#       5 trainer = ChatterBotCorpusTrainer(chatbot)
#
# File ~\anaconda3\lib\site-packages\chatterbot\chatterbot.py:34, in ChatBot.__init__(self, name, **kwargs)
#      31 # Logic adapters used by the chat bot
#      32 self.logic_adapters = []
# ---> 34 self.storage = utils.initialize_class(storage_adapter, **kwargs)
#      36 for adapter in logic_adapters:
#      37     utils.validate_adapter_class(adapter, LogicAdapter)
#
# File ~\anaconda3\lib\site-packages\chatterbot\utils.py:54, in initialize_class(data, *args, **kwargs)
#      51 else:
#      52     Class = import_module(data)
# ---> 54     return Class(*args, **kwargs)
#
# ...

# %% [markdown]
# # ANOTHER TYPE

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# %%
# Data percakapan pelatihan
conversations = [
    ("Halo", "Halo, ada yang bisa saya bantu?"),
    ("Bagaimana cara memesan?", "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini."),
    ("Terima kasih", "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami.")
]

# Memisahkan pertanyaan dan jawaban
questions = []
answers = []
for question, answer in conversations:
    questions.append(question)
    answers.append(answer)

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions + answers)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions)
answers_sequences = tokenizer.texts_to_sequences(answers)

# Padding urutan token menjadi panjang yang sama
max_sequence_length = max(len(seq) for seq in questions_sequences + answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_sequence_length, padding="post")
answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_sequence_length, padding="post")

# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_sequence_length))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
answers_sequences = tokenizer.texts_to_sequences(answers)

# Pemeriksaan dimensi matriks sebelum pemanggilan model.fit()
print("Dimensi questions_sequences_padded:", questions_sequences_padded.shape)
print("Dimensi answers_sequences_padded:", answers_sequences_padded.shape)

# Melatih model
model.fit(questions_sequences_padded, answers_sequences_padded, epochs=50)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_sequence_length, padding="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = tf.argmax(predicted, axis=-1).numpy()[0]
    return tokenizer.index_word[predicted_word_index]

# Contoh penggunaan chatbot
while True:
    user_input = input("User: ")
    answer = generate_answer(user_input)
    print("Chatbot:", answer)
# Out:
# Dimensi questions_sequences_padded: (3, 13)
# Dimensi answers_sequences_padded: (3, 13)
# Epoch 1/50
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[3], line 46
#      43 print("Dimensi answers_sequences_padded:", answers_sequences_padded.shape)
#      45 # Melatih model
# ---> 46 model.fit(questions_sequences_padded, answers_sequences_padded, epochs=50)
#      48 # Fungsi untuk mendapatkan jawaban dari pertanyaan
#      49 def generate_answer(question):
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
# ...

# %%
# Data percakapan pelatihan
conversations = [
    ("Halo", "Halo, ada yang bisa saya bantu?"),
    ("Bagaimana cara memesan?", "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini."),
    ("Terima kasih", "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami.")
]

# Memisahkan pertanyaan dan jawaban
questions = []
answers = []
for question, answer in conversations:
    questions.append(question)
    answers.append(answer)

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions + answers)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions)
answers_sequences = tokenizer.texts_to_sequences(answers)

# Padding urutan token menjadi panjang yang sama
max_question_length = max(len(seq) for seq in questions_sequences)
max_answer_length = max(len(seq) for seq in answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post")
answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_answer_length, padding="post")

# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_question_length))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])

# Melatih model
model.fit(questions_sequences_padded, np.array(answers_sequences_padded), epochs=50)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_question_length, padding="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = np.argmax(predicted[0])
    predicted_word = tokenizer.index_word[predicted_word_index]
    return predicted_word

# Contoh penggunaan chatbot
while True:
    user_input = input("User: ")
    answer = generate_answer(user_input)
    print("Chatbot:", answer)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[10], line 42
#      39 model.compile(optimizer="adam", loss="sparse_categorical_crossentropy", metrics=["accuracy"])
#      41 # Melatih model
# ---> 42 model.fit(questions_sequences_padded, np.array(answers_sequences_padded), epochs=50)
#      44 # Fungsi untuk mendapatkan jawaban dari pertanyaan
#      45 def generate_answer(question):
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
# Data percakapan pelatihan
conversations = [
    ("Halo", "Halo, ada yang bisa saya bantu?"),
    ("Bagaimana cara memesan?", "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini."),
    ("Terima kasih", "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami.")
]

# Memisahkan pertanyaan dan jawaban
questions = []
answers = []
for question, answer in conversations:
    questions.append(question)
    answers.append(answer)

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions + answers)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions)
answers_sequences = tokenizer.texts_to_sequences(answers)

# Padding urutan token menjadi panjang yang sama
max_question_length = max(len(seq) for seq in questions_sequences)
max_answer_length = max(len(seq) for seq in answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post")
answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_answer_length, padding="post")

# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_question_length))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Melatih model
model.fit(questions_sequences_padded, np.array(answers_sequences_padded[:,:-1]), epochs=50)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_question_length, padding="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = np.argmax(predicted[0])
    predicted_word = tokenizer.index_word[predicted_word_index]
    return predicted_word

# Contoh penggunaan chatbot
while True:
    user_input = input("User: ")
    answer = generate_answer(user_input)
    print("Chatbot:", answer)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 42
#      39 model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])
#      41 # Melatih model
# ---> 42 model.fit(questions_sequences_padded, np.array(answers_sequences_padded[:,:-1]), epochs=50)
#      44 # Fungsi untuk mendapatkan jawaban dari pertanyaan
#      45 def generate_answer(question):
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
# Data percakapan pelatihan
conversations = [
    ("Halo", "Halo, ada yang bisa saya bantu?"),
    ("Bagaimana cara memesan?", "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini."),
    ("Terima kasih", "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami.")
]

# Memisahkan pertanyaan dan jawaban
questions = []
answers = []
for question, answer in conversations:
    questions.append(question)
    answers.append(answer)

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions + answers)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions)
answers_sequences = tokenizer.texts_to_sequences(answers)

# Padding urutan token menjadi panjang yang sama
max_question_length = max(len(seq) for seq in questions_sequences)
max_answer_length = max(len(seq) for seq in answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post", truncating="post")
answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_answer_length, padding="post", truncating="post")

# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_question_length))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Melatih model
answers_sequences_padded_input = to_categorical(answers_sequences_padded, num_classes=vocab_size)
model.fit(questions_sequences_padded, answers_sequences_padded_input, epochs=50)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_question_length, padding="post", truncating="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = np.argmax(predicted[0])
    predicted_word = tokenizer.index_word[predicted_word_index]
    return predicted_word

# Contoh penggunaan chatbot
while True:
    user_input = input("User: ")
    answer = generate_answer(user_input)
    print("Chatbot:", answer)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 43
#      41 # Melatih model
#      42 answers_sequences_padded_input = to_categorical(answers_sequences_padded, num_classes=vocab_size)
# ---> 43 model.fit(questions_sequences_padded, answers_sequences_padded_input, epochs=50)
#      45 # Fungsi untuk mendapatkan jawaban dari pertanyaan
#      46 def generate_answer(question):
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding, Reshape
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

# Data percakapan pelatihan
conversations = [
    ("Halo", "Halo, ada yang bisa saya bantu?"),
    ("Bagaimana cara memesan?", "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini."),
    ("Terima kasih", "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami.")
]

# Memisahkan pertanyaan dan jawaban
questions = []
answers = []
for question, answer in conversations:
    questions.append(question)
    answers.append(answer)

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions + answers)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions)
answers_sequences = tokenizer.texts_to_sequences(answers)

# Padding urutan token menjadi panjang yang sama
max_question_length = max(len(seq) for seq in questions_sequences)
max_answer_length = max(len(seq) for seq in answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post", truncating="post")
answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_answer_length, padding="post", truncating="post")

# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_question_length))
model.add(LSTM(128))
model.add(Reshape((128, 1)))  # Menambahkan lapisan Reshape
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Melatih model
answers_sequences_padded_input = to_categorical(answers_sequences_padded, num_classes=vocab_size)
model.fit(questions_sequences_padded, answers_sequences_padded_input, epochs=50)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_question_length, padding="post", truncating="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = np.argmax(predicted[0])
    predicted_word = tokenizer.index_word[predicted_word_index]
    return predicted_word

# Contoh penggunaan chatbot
while True:
    user_input = input("User: ")
    answer = generate_answer(user_input)
    print("Chatbot:", answer)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 52
#      50 # Melatih model
#      51 answers_sequences_padded_input = to_categorical(answers_sequences_padded, num_classes=vocab_size)
# ---> 52 model.fit(questions_sequences_padded, answers_sequences_padded_input, epochs=50)
#      54 # Fungsi untuk mendapatkan jawaban dari pertanyaan
#      55 def generate_answer(question):
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Data percakapan pelatihan
questions_training = [
    "Halo",
    "Bagaimana cara memesan?",
    "Terima kasih"
]

answers_training = [
    "Halo, ada yang bisa saya bantu?",
    "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini.",
    "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami."
]

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions_training + answers_training)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions)
answers_sequences = tokenizer.texts_to_sequences(answers)

# Padding urutan token menjadi panjang yang sama
max_question_length = max(len(seq) for seq in questions_sequences)
max_answer_length = max(len(seq) for seq in answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post", truncating="post")
answers_sequences_sparse = tf.keras.utils.to_categorical(answers_sequences_padded, num_classes=vocab_size)


# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_question_length))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=["sparse_categorical_accuracy"])

# Melatih model
model.fit(questions_sequences_padded, answers_sequences_sparse, epochs=50, batch_size=1)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_question_length, padding="post", truncating="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = np.argmax(predicted[0])
    predicted_word = tokenizer.word_index.get(predicted_word_index, "<OOV>")
    return predicted_word

# Contoh penggunaan chatbot
while True:
    user_input = input("User: ")
    answer = generate_answer(user_input)
    print("Chatbot:", answer)
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 49
#      46 model.compile(optimizer="adam", loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=["sparse_categorical_accuracy"])
#      48 # Melatih model
# ---> 49 model.fit(questions_sequences_padded, answers_sequences_sparse, epochs=50, batch_size=1)
#      51 # Fungsi untuk mendapatkan jawaban dari pertanyaan
#      52 def generate_answer(question):
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
import numpy as np

# Data percakapan pelatihan
questions_training = [
    "Halo",
    "Bagaimana cara memesan?",
    "Terima kasih"
]

answers_training = [
    "Halo, ada yang bisa saya bantu?",
    "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini.",
    "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami."
]

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions_training + answers_training)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions)
answers_sequences = tokenizer.texts_to_sequences(answers)

# Padding urutan token menjadi panjang yang sama
max_question_length = max(len(seq) for seq in questions_sequences)
max_answer_length = max(len(seq) for seq in answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post", truncating="post")
answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_answer_length, padding="post", truncating="post")
answers_sequences_sparse = np.argmax(answers_sequences_padded, axis=2)


# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_question_length))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=["sparse_categorical_accuracy"])

# Melatih model
model.fit(questions_sequences_padded, answers_sequences_sparse, epochs=50, batch_size=1)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_question_length, padding="post", truncating="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = np.argmax(predicted[0])
    predicted_word = tokenizer.word_index.get(predicted_word_index, "<OOV>")
    return predicted_word
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[29], line 37
#      35 questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post", truncating="post")
#      36 answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_answer_length, padding="post", truncating="post")
# ---> 37 answers_sequences_sparse = np.argmax(answers_sequences_padded, axis=2)
#      40 # Membangun model chatbot
#      41 model = Sequential()
#
# File <__array_function__ internals>:5, in argmax(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:1195, in argmax(a, axis, out)
#    1121 @array_function_dispatch(_argmax_dispatcher)
#    1122 def argmax(a, axis=None, out=None):
#    1123     """
#    1124     Returns the indices of the maximum values along an axis.
#    1125
#    (...)
#    1193
#    1194     """
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Data percakapan pelatihan
questions_training = [
    "Halo",
    "Bagaimana cara memesan?",
    "Terima kasih"
]

answers_training = [
    "Halo, ada yang bisa saya bantu?",
    "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini.",
    "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami."
]

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions_training + answers_training)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions_training)
answers_sequences = tokenizer.texts_to_sequences(answers_training)

# Padding urutan token menjadi panjang yang sama
max_question_length = max(len(seq) for seq in questions_sequences)
max_answer_length = max(len(seq) for seq in answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post", truncating="post")
answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_answer_length, padding="post", truncating="post")

# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_question_length))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=["sparse_categorical_accuracy"])

# Melatih model
model.fit(questions_sequences_padded, answers_sequences_padded, epochs=50, batch_size=1)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_question_length, padding="post", truncating="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = tf.argmax(predicted, axis=-1).numpy()[0]
    predicted_word = tokenizer.index_word.get(predicted_word_index, "<OOV>")
    return predicted_word
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[30], line 47
#      44 model.compile(optimizer="adam", loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics=["sparse_categorical_accuracy"])
#      46 # Melatih model
# ---> 47 model.fit(questions_sequences_padded, answers_sequences_padded, epochs=50, batch_size=1)
#      49 # Fungsi untuk mendapatkan jawaban dari pertanyaan
#      50 def generate_answer(question):
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# Data percakapan pelatihan
questions_training = [
    "Halo",
    "Bagaimana cara memesan?",
    "Terima kasih"
]

answers_training = [
    "Halo, ada yang bisa saya bantu?",
    "Anda dapat memesan melalui situs web kami atau menghubungi kami di nomor ini.",
    "Sama-sama! Jika Anda memiliki pertanyaan lain, jangan ragu untuk menghubungi kami."
]

# Tokenisasi teks
tokenizer = Tokenizer(oov_token="<OOV>")
tokenizer.fit_on_texts(questions_training + answers_training)

# Mendapatkan total kata dalam vocabulary
vocab_size = len(tokenizer.word_index) + 1

# Mengonversi teks ke dalam urutan token
questions_sequences = tokenizer.texts_to_sequences(questions)
answers_sequences = tokenizer.texts_to_sequences(answers)

# Padding urutan token menjadi panjang yang sama
max_question_length = max(len(seq) for seq in questions_sequences)
max_answer_length = max(len(seq) for seq in answers_sequences)
questions_sequences_padded = pad_sequences(questions_sequences, maxlen=max_question_length, padding="post", truncating="post")
answers_sequences_padded = pad_sequences(answers_sequences, maxlen=max_answer_length, padding="post", truncating="post")

# Membangun model chatbot
model = Sequential()
model.add(Embedding(vocab_size, 128, input_length=max_question_length))
model.add(LSTM(128))
model.add(Dense(vocab_size, activation="softmax"))

# Kompilasi model
model.compile(optimizer="adam", loss='sparse_categorical_crossentropy', metrics=["sparse_categorical_accuracy"])


# Melatih model
model.fit(questions_sequences_padded, answers_sequences_padded, epochs=50, batch_size=1)

# Fungsi untuk mendapatkan jawaban dari pertanyaan
def generate_answer(question):
    question_seq = tokenizer.texts_to_sequences([question])
    question_seq_padded = pad_sequences(question_seq, maxlen=max_question_length, padding="post", truncating="post")
    predicted = model.predict(question_seq_padded)
    predicted_word_index = tf.argmax(predicted, axis=-1).numpy()[0]
    predicted_word = tokenizer.index_word.get(predicted_word_index, "<OOV>")
    return predicted_word
# Out:
# Epoch 1/50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 48
#      44 model.compile(optimizer="adam", loss='sparse_categorical_crossentropy', metrics=["sparse_categorical_accuracy"])
#      47 # Melatih model
# ---> 48 model.fit(questions_sequences_padded, answers_sequences_padded, epochs=50, batch_size=1)
#      50 # Fungsi untuk mendapatkan jawaban dari pertanyaan
#      51 def generate_answer(question):
#
# File ~\anaconda3\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# ...
